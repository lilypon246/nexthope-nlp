# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report, accuracy_score

# %%
df = pd.read_csv("./datasets/Scraping_preprocessing_v2.csv")
content = df['content']

# %%
vectorizer = TfidfVectorizer()

# %%
X = vectorizer.fit_transform(content)

# %%
vectorizer.vocabulary_
# Out:
# {'abai': 718,
#  'dishare': 6430,
#  'manis': 15072,
#  'nya': 17886,
#  'ruu': 21211,
#  'kesehatanyang': 12918,
#  'halusinasi': 9062,
#  'tanggung': 23651,
#  'jawabkantanya': 11622,
#  'data': 5296,
#  'genom': 8349,
#  'bocor': 3412,
#  'stunting': 23218,
#  'jamban': 11533,
#  'bersih': 2894,
#  'alat': 1191,
#  'usg': 25187,
#  'tbc': 23757,
#  'mati': 15300,
#  'lahir': 14018,
#  'duga': 6925,
#  'jual': 11905,
#  'juta': 11997,
#  'pasien': 18733,
#  'diserver': 6427,
#  'kemenkes': 12722,
#  'kerja': 12866,
#  'buruk': 4259,
#  'sejarahso': 21817,
#  'ayo': 2091,
#  'kalo': 12192,
#  'peduli': 18874,
#  'lindung': 14489,
#  'kicepdata': 13063,
#  'fatal': 7641,
#  'loh': 14604,
#  'pegang': 18900,
#  'tau': 23723,
#  'lemah': 14330,
#  'orang': 18307,
#  'indonesia': 10929,
#  'otak': 18373,
#  'mu': 16388,
#  'kesitu': 12934,
#  'mikirnya': 16002,
#  'bil': 3091,
#  'polos': 19764,
#  'banget': 2300,
#  'sih': 22477,
#  'panik': 18624,
#  'dibuatin': 5827,
#  'kartu': 12340,
#  'kredit': 13699,
#  'bank': 2347,
#  'gua': 8745,
#  'pas': 18726,
#  'ditawarin': 6516,
#  'iya2': 11433,
#  'paham': 18496,
#  'untung': 25089,
#  'gercep': 8373,
#  'sinkron': 22595,
#  'benaran': 2695,
#  'dipakai': 6232,
#  'registrasi': 20689,
#  'motor': 16332,
#  'dimintadiakuin': 6183,
#  'ya': 25962,
#  'tang': 23623,
#  'berani': 2764,
#  'janji': 11565,
#  'asing': 1865,
#  'akibat': 1089,
#  'perang': 19202,
#  'biologis': 3142,
#  'efek': 7082,
#  'oknum': 18159,
#  'mas': 15170,
#  'breach': 3991,
#  'usaha': 25158,
#  'jamin': 11536,
#  'dok': 6719,
#  'jujur': 11954,
#  'keri': 12862,
#  'masyarakat': 15255,
#  'obat': 18074,
#  'racun': 20371,
#  'beda': 2570,
#  'dosis': 6799,
#  'uu': 25229,
#  'manusia': 15099,
#  'entar': 7360,
#  'jajah': 11499,
#  'bahaya': 2203,
#  'tubuh': 24725,
#  'indonesiadata': 10939,
#  'mingkem': 16071,
#  'scam': 21596,
#  'kemarin': 12692,
#  'danamon': 5226,
#  'bni': 3369,
#  'hati': 9184,
#  'guys': 8828,
#  'chat': 4635,
#  'nomor': 17740,
#  'klik': 13215,
#  'link': 14510,
#  'takut': 23572,
#  'saldo': 21334,
#  'hilang': 9391,
#  'halo': 9050,
#  'selamat': 21881,
#  'siang': 22404,
#  'konsumen': 13527,
#  'shopee': 22362,
#  'barusan': 2440,
#  'terima': 24038,
#  'telepon': 23871,
#  'tipu': 24348,
#  'mengatasnamakan': 15640,
#  'nama': 16647,
#  'lengkapalamat': 14364,
#  'mohon': 16269,
#  'tindak': 24311,
#  'case': 4452,
#  'resah': 20837,
#  'kasih': 12368,
#  'nik': 17594,
#  'beli': 2662,
#  'motormotornya': 16333,
#  'pajak': 18510,
#  'alamat': 1174,
#  'dunia': 6990,
#  'giring': 8509,
#  'tuju': 24751,
#  'digitalnanti': 5966,
#  'mudah': 16407,
#  'anjirkasian': 1526,
#  'hp': 9536,
#  'pulsa': 20243,
#  'internet': 11201,
#  'butuh': 4280,
#  'makan': 14889,
#  'susah': 23391,
#  'najis': 16632,
#  'hotel': 9527,
#  'kelas': 12630,
#  'unjung': 25067,
#  'fyi': 7947,
#  'spam': 22965,
#  '2017': 254,
#  'wajib': 25444,
#  'ulang': 24972,
#  'pakai': 18520,
#  'ktp': 13766,
#  'duduk': 6920,
#  'sampahmudah': 21387,
#  'update': 25103,
#  'temu': 23945,
#  'etc': 7448,
#  'suka': 23286,
#  'line': 14500,
#  'whatsapp': 25656,
#  'nomer': 17733,
#  'mikir': 15998,
#  'tuh': 24735,
#  'btc': 4105,
#  'sorr': 22918,
#  'bosan': 3908,
#  'harga': 9137,
#  'market': 15146,
#  'turun': 24830,
#  'kasihan': 12369,
#  'pinjol': 19524,
#  'gembel': 8305,
#  'kantor': 12279,
#  'ku': 13794,
#  'sop': 22898,
#  'buka': 4168,
#  'website': 25601,
#  'websiteapp': 25603,
#  'resmi': 20855,
#  'komputer': 13469,
#  'kantorkalo': 12282,
#  'auto': 2009,
#  'sapa': 21480,
#  'bi': 3026,
#  'salah': 21307,
#  'pegawai': 18902,
#  'teledor': 23852,
#  'ngelanggar': 17249,
#  'deh': 5507,
#  'rame': 20496,
#  'sekian': 21849,
#  'puluh': 20249,
#  'lengkap': 14362,
#  'lai': 14033,
#  'hudiya': 10573,
#  'bkl': 3245,
#  'kejar': 12594,
#  'sakya': 21303,
#  'personal': 19333,
#  'perusaahan': 19365,
#  'naye': 16797,
#  'doang': 6685,
#  'but': 4276,
#  'semoga': 21995,
#  'baning': 2342,
#  'cepat': 4553,
#  'ketangkep': 12948,
#  'biar': 3031,
#  'tenang': 23951,
#  'heran': 9309,
#  'tiktok': 24279,
#  'mah': 14839,
#  'ttangga': 24704,
#  'kerudung': 12897,
#  '30rb': 420,
#  'cod': 4810,
#  '80rb': 652,
#  'menerima': 15606,
#  'emaknya': 7240,
#  'langsung': 14139,
#  'bayar': 2505,
#  'cek': 4499,
#  'seller': 21931,
#  'lacak': 13957,
#  'maksud': 14930,
#  'ri': 20930,
#  'kencang': 12776,
#  'kominfo': 13374,
#  'suara': 23227,
#  'cuman': 5087,
#  'kayak': 12426,
#  'iya': 11431,
#  'gue': 8760,
#  'darimana': 5265,
#  '94': 686,
#  'sanksi': 21453,
#  'tegur': 23813,
#  'langgar': 14134,
#  'besarbesaran': 2943,
#  'hantam': 9104,
#  'india': 10872,
#  'identitas': 10696,
#  'detail': 5630,
#  'pribadi': 19956,
#  'online': 18218,
#  'iring': 11284,
#  'maju': 14882,
#  'teknologi': 23832,
#  'risiko': 20998,
#  'tingkat': 24325,
#  'milik': 16023,
#  'mobil': 16230,
#  'listrik': 14536,
#  'spklu': 23026,
#  'shell': 22335,
#  'jalan': 11515,
#  'menahan': 15550,
#  'nang': 16693,
#  'teror': 24091,
#  'psikis': 20175,
#  'kena': 12763,
#  'menikmati': 15725,
#  'duit': 6934,
#  'kagak': 12097,
#  'kemana2': 12666,
#  'indihome': 10882,
#  'enggak': 7326,
#  'mau': 15312,
#  'okeee': 18152,
#  'aman': 1289,
#  'nasib': 16764,
#  'datae': 5332,
#  'seng': 22074,
#  'ngunuku': 17541,
#  'piye': 19582,
#  'monggo': 16287,
#  'sangkut': 21448,
#  'lohojok': 14615,
#  'takok': 23567,
#  'ta': 23490,
#  'wes': 25639,
#  'biometric': 3143,
#  'ragu': 20392,
#  'kali': 12158,
#  'institusi': 11143,
#  'korporasi': 13609,
#  'negara': 16847,
#  'state': 23123,
#  'surveilllance': 23380,
#  'prc': 19904,
#  'mek': 15429,
#  'ngandani': 17042,
#  'sing': 22573,
#  'iki': 10759,
#  'iso': 11322,
#  'lho': 14429,
#  'menuntut': 15809,
#  'jaga': 11479,
#  'rahasia': 20395,
#  'datasak': 5395,
#  'uopooo': 25096,
#  'tunjukkan': 24812,
#  'sistem': 22637,
#  'ufah': 24930,
#  'kecap': 12533,
#  'lo': 14567,
#  'ngab': 16969,
#  'dongok': 6765,
#  'februari': 7666,
#  '1998': 198,
#  'puncak': 20253,
#  'oktober': 18166,
#  'paska': 18737,
#  'bupati': 4241,
#  'jawa': 11607,
#  '1999': 199,
#  'minim': 16074,
#  'literasi': 14544,
#  'tolol': 24490,
#  'menyampah': 15821,
#  'twiter': 24859,
#  'bertahun2': 2906,
#  '2023': 280,
#  'bahas': 2198,
#  'rumor': 21181,
#  'katrol': 12407,
#  'saham': 21265,
#  'label': 13952,
#  'artis': 1820,
#  'nyaman': 17921,
#  'parah': 18677,
#  'abang': 722,
#  'wamil': 25490,
#  'kacau': 12054,
#  'balau': 2261,
#  'nasabah': 16745,
#  'bsi': 4079,
#  'ojk': 18136,
#  'awas': 2039,
#  'komplen': 13457,
#  'berbusah2': 2797,
#  'gakan': 8046,
#  'wkwkwk': 25778,
#  'yaudah': 26086,
#  'ikhlas': 10755,
#  'ulah': 24969,
#  'hooo': 9512,
#  'kapal': 12290,
#  'bekas': 2641,
#  'mahal': 14842,
#  'nyata': 17951,
#  'hitung': 9430,
#  'investigasi': 11251,
#  'media': 15391,
#  'bredel': 4010,
#  'blackrock': 3269,
#  'kelola': 12649,
#  'dana': 5224,
#  'pensiun': 19158,
#  'vanguard': 25282,
#  'eksklusif': 7157,
#  'masuktapi': 15248,
#  'panama': 18591,
#  'paper': 18669,
#  'dll': 6629,
#  'pindah': 19509,
#  'amrik': 1387,
#  'gin': 8482,
#  'lets': 14391,
#  'sayang': 21559,
#  'kepake': 12804,
#  'alah': 1169,
#  'tahi': 23531,
#  'kotok': 13641,
#  'niat': 17566,
#  'selamatin': 21882,
#  'dukun': 6951,
#  'eh': 7109,
#  'gera': 8364,
#  'ninja': 17633,
#  'pecah': 18862,
#  'geger': 8265,
#  'santet': 21468,
#  'cegah': 4496,
#  'serang': 22171,
#  'masif': 15196,
#  'manfaat': 15040,
#  'jatuh': 11599,
#  'orde': 18331,
#  'betulbanget': 2974,
#  'percaya': 19220,
#  'id': 10677,
#  'selfie': 21919,
#  'toko': 24455,
#  'ijo': 10748,
#  'oren': 18338,
#  'rip': 20990,
#  'privacy': 20002,
#  'tolong': 24498,
#  'tulis': 24772,
#  'lolos': 14632,
#  'lupa': 14748,
#  'email': 7233,
#  'berkas': 2850,
#  'isi': 11305,
#  'web': 25586,
#  'rekrutmen': 20736,
#  'hapus': 9116,
#  'total': 24532,
#  'gagal': 8011,
#  'tes': 24141,
#  'kait': 12118,
#  'download': 6807,
#  'aplikasi': 1724,
#  'ilegal': 10782,
#  'uang': 24887,
#  'masuk': 15242,
#  'rekening': 20722,
#  'mencolong': 15583,
#  'modem': 16248,
#  'salam': 21331,
#  'sejahtera': 21812,
#  'credit': 5014,
#  'collector': 4838,
#  'akses': 1105,
#  'jtk': 11901,
#  'maklumat': 14911,
#  'hutang': 10614,
#  'legal': 14294,
#  'jaring': 11579,
#  'smartfren': 22767,
#  'trouble': 24664,
#  'paket': 18537,
#  'habiss': 8871,
#  'wkwkw': 25774,
#  'minn': 16093,
#  'murah': 16487,
#  'kantong': 12277,
#  'nih': 17577,
#  'saran': 21489,
#  'hehe': 9256,
#  'gratis': 8711,
#  'coblos': 4804,
#  'ganjar': 8122,
#  'den': 5550,
#  'bokep': 3841,
#  'maaf': 14779,
#  'sumpah': 23317,
#  'incompetency': 10853,
#  'ngerugiin': 17348,
#  'njiiiiir': 17668,
#  'database': 5312,
#  'bkpsdm': 3254,
#  'kabupaten': 12046,
#  'sampang': 21390,
#  'retas': 20889,
#  'hacker': 8884,
#  'milad': 16013,
#  'leaks': 14258,
#  'sensitif': 22099,
#  'pns': 19702,
#  'lingkung': 14504,
#  'pemkab': 19027,
#  'potong': 19851,
#  'nder': 16821,
#  'habis': 8865,
#  'tarik': 23703,
#  'minus': 16114,
#  'wokwwowkwowlw': 25855,
#  'get': 8394,
#  'contact': 4917,
#  'curiga': 5105,
#  'kandung': 12255,
#  'bukaaan': 4169,
#  'mbankingnya': 15343,
#  'error': 7414,
#  'min': 16048,
#  'telponin': 23908,
#  'asuransi': 1928,
#  'life': 14462,
#  'telpon': 23905,
#  'app': 1742,
#  'peniputapi': 19139,
#  'no': 17695,
#  'menunggu': 15808,
#  'cetak': 4587,
#  'mbak': 15337,
#  'lurah': 14758,
#  'disuru': 6480,
#  'donlot': 6775,
#  'digital': 5946,
#  'mudahan': 16408,
#  'kemendagri': 12713,
#  'dont': 6779,
#  'mess': 15927,
#  'this': 24218,
#  'one': 18208,
#  'up': 25097,
#  'dmn2': 6669,
#  'lu': 14701,
#  'sebar': 21684,
#  'jail': 11496,
#  'mending': 15594,
#  'ganti': 8130,
#  'lazadong': 14235,
#  'info': 10983,
#  'langgan': 14132,
#  'just': 11993,
#  'baca': 2122,
#  'bakar': 2242,
#  'yaudahlah': 26087,
#  'belanja': 2658,
#  'favorit': 7646,
#  'ep': 7381,
#  'nextmya': 16960,
#  'wkwk': 25755,
#  'tanggal': 23641,
#  'telp': 23902,
#  '02130200368': 7,
#  'menawari': 15571,
#  'cimb': 4715,
#  'ngambil': 17022,
#  'freeport': 7887,
#  '100': 31,
#  'katanyangambil': 12393,
#  'pilot': 19497,
#  'culik': 5082,
#  'sulitsama': 23303,
#  'wowo': 25898,
#  'buta': 4277,
#  'databocor': 5317,
#  'ria': 20931,
#  'laptop': 14176,
#  'disalahin': 6373,
#  'karyawan': 12351,
#  'era': 7396,
#  'rawan': 20583,
#  'kecuali': 12551,
#  'pln': 19657,
#  'nak': 16634,
#  'cakap': 4353,
#  'malaysia': 14946,
#  'rakyat': 20450,
#  'daftar': 5166,
#  'mysejahtera': 16565,
#  'samping': 21400,
#  'job': 11831,
#  'portal': 19817,
#  'bawa': 2488,
#  'hape': 9108,
#  'batre': 2480,
#  'tetheringan': 24160,
#  'kabel': 12038,
#  'android': 1448,
#  'ip': 11263,
#  'pbnya': 18832,
#  'yaampun': 25979,
#  'kak': 12122,
#  'ngemc': 17286,
#  'perintah': 19267,
#  'mesti': 15931,
#  'ijazah': 10743,
#  'minimal': 16075,
#  'd3': 5149,
#  'lulus': 14732,
#  'smk': 22779,
#  'alam': 1172,
#  'lihat': 14468,
#  'disubmit': 6475,
#  'duluan': 6960,
#  'gampang': 8103,
#  'mengasih': 15638,
#  'kadang': 12068,
#  'tagih': 23522,
#  'dasar': 5291,
#  'meter': 15949,
#  'asumsi': 1925,
#  'gara': 8151,
#  'tugas': 24733,
#  'catat': 4462,
#  'plnnya': 19662,
#  'menembak': 15601,
#  'visit': 25359,
#  'rumah2': 21171,
#  'baneran': 2294,
#  'dibenerin': 5789,
#  'disdukcapil': 6405,
#  'otonomi': 18384,
#  'dinas': 6196,
#  'tri': 24632,
#  'mou': 16335,
#  'phew': 19423,
#  'pagi': 18487,
#  'peras': 19207,
#  'sosial': 22924,
#  'pade': 18480,
#  'luas': 14707,
#  'paranormal': 18685,
#  'obl': 18078,
#  'survey': 23381,
#  'bpjs': 3948,
#  'uups': 25237,
#  'wakil': 25462,
#  'menteri': 15780,
#  'bumn': 4214,
#  'ii': 10739,
#  'kartika': 12339,
#  'wirjoatmodjo': 25715,
#  'ambil': 1339,
#  'cabang': 4328,
#  'duh': 6928,
#  'aneh': 1452,
#  'bri': 4016,
#  'siber': 22436,
#  'wamen': 25489,
#  'jenis': 11719,
#  'byu': 4321,
#  'sik': 22501,
#  'asik': 1862,
#  'sms': 22788,
#  'mulu': 16443,
#  'pinjam': 19519,
#  'sosmed': 22930,
#  'nit': 17653,
#  'kampus': 12222,
#  'tuanya': 24719,
#  'valeri': 25268,
#  'jo': 11830,
#  'staff': 23090,
#  'khusus': 13051,
#  'toyota': 24542,
#  'rugi': 21159,
#  'edward': 7070,
#  'snowden': 22817,
#  '10': 30,
#  'kawal': 12415,
#  'httpstcoafbsu8zxpb': 9748,
#  'washington': 25547,
#  '2013': 250,
#  'kontraktor': 13561,
#  'as': 1830,
#  'kejut': 12602,
#  'dedah': 5476,
#  'bah': 2189,
#  'teman': 23917,
#  'konfirmasi': 13492,
#  'suruh': 23376,
#  'gunain': 8788,
#  'capek': 4415,
#  'ohhhhh': 18121,
#  'js': 11898,
#  'kah': 12108,
#  'ditindaklanjuti': 6544,
#  'sembarang': 21967,
#  'disayngkan': 6392,
#  'bingung': 3125,
#  'pesan': 19379,
#  'datadata': 5326,
#  'sesuai': 22262,
#  'lapor': 14168,
#  'kemana': 12665,
#  'kuatir': 13810,
#  'cs': 5035,
#  'gaperlu': 8142,
#  'selesai': 21909,
#  'urus': 25142,
#  'psikolog': 20177,
#  'sesi': 22256,
#  'konsultasi': 13526,
#  'lenyap': 14372,
#  'cari': 4444,
#  'arti': 1815,
#  'dokumen': 6728,
#  'anggap': 1467,
#  'intern': 11193,
#  'twitter': 24863,
#  'please': 19641,
#  'your': 26157,
#  'magic': 14835,
#  'ngaku2': 17004,
#  'lazada': 14233,
#  'rumah': 21170,
#  'barang': 2412,
#  'nelpon': 16895,
#  'ngisi': 17439,
#  'bicara': 3055,
#  'kasar': 12359,
#  'customer': 5111,
#  'tibatiba': 24259,
#  'us': 25154,
#  'asli': 1877,
#  'wkwkwkwk': 25800,
#  'user': 25178,
#  'kontak': 13538,
#  'real': 20605,
#  'ancam': 1415,
#  'joki': 11855,
#  'backup': 2134,
#  'syukur': 23478,
#  'fee': 7670,
#  'informasi': 10998,
#  'simpeg': 22546,
#  'skp': 22714,
#  'tinggal': 24319,
#  'negeri': 16874,
#  'wakanda': 25458,
#  'takutdi': 23575,
#  'nope': 17771,
#  'dengar': 5558,
#  'atm': 1959,
#  'bobol': 3387,
#  'bom': 3855,
#  'rutin': 21208,
#  'sopi': 22903,
#  'pp': 19860,
#  'akun': 1143,
#  'sopay': 22901,
#  'later': 14197,
#  'hybrid': 10634,
#  'kian': 13058,
#  'jamur': 11542,
#  'rentan': 20793,
#  'miris': 16125,
#  'management': 15009,
#  'konser': 13517,
#  'sangka': 21444,
#  'sidi': 22458,
#  'kpk': 13659,
#  'santuy': 21473,
#  'jabat': 11463,
#  'jkw': 11811,
#  'foto': 7851,
#  'papa': 18662,
#  'mengaca': 15611,
#  'muji': 16425,
#  'hasil': 9172,
#  'diet': 5921,
#  'simpan': 22541,
#  'bentuk': 2750,
#  'rnd': 21039,
#  'ternyta': 24082,
#  'analisis': 1405,
#  'eksternal': 7172,
#  'apa': 1627,
#  'gambar': 8080,
#  'qty': 20345,
#  'production': 20046,
#  'pengaruh': 19094,
#  'pricing': 19983,
#  'komponen': 13460,
#  'unit': 25059,
#  'bocorberarti': 3461,
#  'valid': 25269,
#  'curang': 5097,
#  'sistematis': 22639,
#  'layak': 14223,
#  'tangkap': 23661,
#  'ketua': 13000,
#  'toch': 24437,
#  'khawatir': 13037,
#  'besok': 2950,
#  'proses': 20108,
#  'hukum': 10588,
#  'wni': 25838,
#  'dukung': 6953,
#  'jkwwalau': 11813,
#  'maya': 15322,
#  'kpkyg': 13661,
#  'mengikuti': 15696,
#  '60rbpas': 588,
#  'join': 11847,
#  'group': 8730,
#  'telegram': 23854,
#  'blokir': 3319,
#  'ajasaran': 1031,
#  'ponsel': 19787,
#  'utama': 25206,
#  'mengaku': 15622,
#  'telkomsel': 23895,
#  'bilang': 3093,
#  'pencet': 19062,
#  'angka': 1480,
#  'karen': 12321,
#  'kaget': 12101,
#  'gaakan': 7958,
#  'laku': 14083,
#  'ratus': 20578,
#  'ribu': 20945,
#  'bocorhttpstco2fuhljwcng': 3546,
#  'anwar': 1601,
#  'usman': 25194,
#  'mengomong': 15709,
#  'putus': 20313,
#  'lanjur': 14142,
#  'ngefoto': 17192,
#  'hiiatut': 9380,
#  'contoh': 4926,
#  'resiko': 20852,
#  'kendali': 12782,
#  'penuh': 19178,
#  'memutuskan': 15539,
#  'konten': 13543,
#  'nemu': 16907,
#  'hindar': 9405,
#  'dapur': 5258,
#  'klarifikasi': 13193,
#  'denny': 5571,
#  'indrayana': 10968,
#  'mahkamah': 14857,
#  'konstitusi': 13524,
#  'narasi': 16730,
#  'milu': 16039,
#  'keliru': 12644,
#  'bahasa': 2199,
#  'sisi': 22632,
#  '2019': 260,
#  'kontrak': 13559,
#  'ekslusifnya': 7159,
#  'cancel': 4386,
#  'adil': 838,
#  'payment': 18815,
#  'fair': 7578,
#  'kai': 12112,
#  'muka': 16428,
#  'gimanatapi': 8474,
#  'asia': 1857,
#  'arisan': 1801,
#  'kirim': 13110,
#  'kakak': 12124,
#  'tf': 24171,
#  '15jt': 141,
#  'digunain': 5984,
#  'hal': 9034,
#  'bantu': 2375,
#  'rt': 21138,
#  'kronologi': 13738,
#  'ceritain': 4576,
#  'useless': 25175,
#  'bungkus': 4228,
#  'goreng': 8662,
#  'nasi': 16763,
#  'bocorin': 3563,
#  'asa': 1831,
#  '102juta': 53,
#  'tqpi': 24550,
#  'hadap': 8927,
#  'fakta': 7594,
#  'edan': 7058,
#  'doktor': 6724,
#  'bukti': 4187,
#  'konoon': 13509,
#  'konyol': 13569,
#  'status': 23139,
#  'bareskrim': 2426,
#  'integritas': 11167,
#  'keluarga': 12653,
#  'surat': 23360,
#  'ppatk': 19862,
#  'antero': 1580,
#  '40000': 481,
#  'goldheart': 8624,
#  'dakwa': 5201,
#  'tali': 23586,
#  'kuasa': 13803,
#  'sg': 22313,
#  'siasat': 22431,
#  'httpstcox3yba3dldl': 10489,
#  'singapura': 22579,
#  'godam': 8608,
#  'thanks': 24189,
#  'biometrik': 3144,
#  'umbar2': 24991,
#  'oh': 18118,
#  'peribadi': 19250,
#  'mate': 15290,
#  'fhm': 7698,
#  'httpstco82ope3n4oh': 9701,
#  'canggih': 4391,
#  'ken': 12762,
#  'warga': 25513,
#  'konoha': 13506,
#  'sehari2': 21803,
#  'serba': 22178,
#  'unt': 25083,
#  'sera': 22161,
#  'truk': 24677,
#  'guling': 8780,
#  'uninstall': 25054,
#  'sehat': 21805,
#  'arep': 1790,
#  'nyengkeram': 17993,
#  'kim': 13084,
#  'jong': 11871,
#  'un': 25009,
#  'toilet': 24447,
#  'pergi': 19242,
#  'musuh': 16517,
#  'curi': 5102,
#  'diaitu': 5699,
#  'intelijen': 11179,
#  'undi': 25031,
#  'belikan': 2670,
#  'oceania': 18093,
#  'kabar': 12029,
#  'kendara': 12783,
#  'membedakan': 15480,
#  'smartphone': 22768,
#  'lidi': 14457,
#  'digit': 5945,
#  '62': 593,
#  'berita': 2833,
#  'mediamedia': 15394,
#  'medis': 15399,
#  'wenang': 25636,
#  'organisasi': 18344,
#  'profesi': 20059,
#  'kolegium': 13329,
#  'konsil': 13518,
#  'dokter': 6722,
#  'alih': 1231,
#  'paksa': 18555,
#  'omnibuslawpadahal': 18194,
#  'nakes': 16638,
#  'ahli': 964,
#  'mugkin': 16418,
#  'sdm': 21656,
#  'inijika': 11051,
#  'uuharus': 25232,
#  'deteksi': 5638,
#  'hubung': 10568,
#  'etika': 7457,
#  'profesiboleh': 20060,
#  'indak': 10857,
#  'omnibuslaw': 18193,
#  'tangan': 23624,
#  'tahan': 23526,
#  'nasional': 16767,
#  'bayang': 2501,
#  'next': 16957,
#  'pening': 19120,
#  'bangsa': 2326,
#  'buah': 4114,
#  'peta': 19395,
#  'asai': 1834,
#  'asingtiada': 1869,
#  'yuk': 26174,
#  'fix': 7776,
#  'minggu': 16068,
#  'ditlf': 6548,
#  'kenal': 12765,
#  'truecaller': 24676,
#  'dinamain': 6194,
#  'bersama2': 2881,
#  'bnl': 3371,
#  'alas': 1186,
#  'bantuin': 2377,
#  'indonesiadaripada': 10938,
#  'daya': 5427,
#  'thread': 24234,
#  'sponsor': 23034,
#  'liga': 14465,
#  'pasword': 18780,
#  'banking': 2354,
#  'tutup': 24837,
#  'inna': 11097,
#  'lillahi': 14479,
#  'claimed': 4760,
#  'rem': 20757,
#  'khayal': 13042,
#  'genomik': 8351,
#  'ngeri': 17333,
#  'dikirimin': 6089,
#  'sakit': 21294,
#  'bida': 3058,
#  'lamar': 14102,
#  'jobstreet': 11836,
#  'oke': 18148,
#  'ges': 8386,
#  'fud': 7915,
#  'hormat': 9518,
#  'teriak': 24033,
#  'ramai': 20486,
#  'diamtakut': 5727,
#  'rezimkl': 20926,
#  'pastisidang': 18776,
#  'nmn': 17688,
#  'tertutupinila': 24121,
#  'rezim': 20925,
#  'dipertontankan': 6270,
#  '9thn': 697,
#  'sanggup': 21443,
#  'genome': 8350,
#  'bocorjadi': 3580,
#  'slowly': 22757,
#  'bunuh': 4238,
#  'bikin': 3087,
#  'substance': 23247,
#  ...}

# %%
new_df = pd.read_csv('./datasets/labeled_df.csv')
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22740 entries, 0 to 22739
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   content    22740 non-null  object
#  1   sentiment  22740 non-null  object
# dtypes: object(2)
# memory usage: 355.4+ KB

# %%
y = new_df['sentiment']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=200, random_state=42)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
pred = rf.predict(X_test)

# %%
print(classification_report(y_test, pred))
print(accuracy_score(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.96      1.00      0.98      4350
#      neutral       1.00      0.10      0.17        63
#     positive       0.88      0.05      0.10       135
#
#     accuracy                           0.96      4548
#    macro avg       0.94      0.38      0.42      4548
# weighted avg       0.96      0.96      0.94      4548
#
# 0.9591029023746702

# %%
from sklearn import svm

clf = svm.SVC()
clf.fit(X_train, y_train)
# Out:
# SVC()

# %%
pred_2 = clf.predict(X_test)

# %%
print(classification_report(y_test, pred_2))
print(accuracy_score(y_test, pred_2))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.96      1.00      0.98      4350
#      neutral       1.00      0.03      0.06        63
#     positive       0.90      0.07      0.12       135
#
#     accuracy                           0.96      4548
#    macro avg       0.95      0.37      0.39      4548
# weighted avg       0.96      0.96      0.94      4548
#
# 0.9586631486367634
