# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report, accuracy_score

# %%
df = pd.read_csv("./csvfile/Scraping_preprocessing_v2.csv")
content = df['content']

# %%
vectorizer = TfidfVectorizer()

# %%
X = vectorizer.fit_transform(content)

# %%
vectorizer.vocabulary_
# Out:
# {'abai': 718,
#  'dishare': 6430,
#  'manis': 15072,
#  'nya': 17887,
#  'ruu': 21212,
#  'kesehatanyang': 12918,
#  'halusinasi': 9062,
#  'tanggung': 23652,
#  'jawabkantanya': 11622,
#  'data': 5296,
#  'genom': 8349,
#  'bocor': 3412,
#  'stunting': 23219,
#  'jamban': 11533,
#  'bersih': 2894,
#  'alat': 1191,
#  'usg': 25188,
#  'tbc': 23758,
#  'mati': 15300,
#  'lahir': 14018,
#  'duga': 6925,
#  'jual': 11905,
#  'juta': 11997,
#  'pasien': 18734,
#  'diserver': 6427,
#  'kemenkes': 12722,
#  'kerja': 12866,
#  'buruk': 4259,
#  'sejarahso': 21818,
#  'ayo': 2091,
#  'kalo': 12192,
#  'peduli': 18875,
#  'lindung': 14489,
#  'kicepdata': 13063,
#  'fatal': 7641,
#  'loh': 14604,
#  'pegang': 18901,
#  'tau': 23724,
#  'lemah': 14330,
#  'orang': 18308,
#  'indonesia': 10929,
#  'otak': 18374,
#  'mu': 16388,
#  'kesitu': 12934,
#  'mikirnya': 16002,
#  'bil': 3091,
#  'polos': 19765,
#  'banget': 2300,
#  'sih': 22478,
#  'panik': 18625,
#  'dibuatin': 5827,
#  'kartu': 12340,
#  'kredit': 13699,
#  'bank': 2347,
#  'gua': 8745,
#  'pas': 18727,
#  'ditawarin': 6516,
#  'iya2': 11433,
#  'paham': 18497,
#  'untung': 25090,
#  'gercep': 8373,
#  'sinkron': 22596,
#  'benaran': 2695,
#  'dipakai': 6232,
#  'registrasi': 20690,
#  'motor': 16332,
#  'dimintadiakuin': 6183,
#  'ya': 25963,
#  'tang': 23624,
#  'berani': 2764,
#  'janji': 11565,
#  'asing': 1865,
#  'akibat': 1089,
#  'perang': 19203,
#  'biologis': 3142,
#  'efek': 7082,
#  'oknum': 18160,
#  'mas': 15170,
#  'breach': 3991,
#  'usaha': 25159,
#  'jamin': 11536,
#  'dok': 6719,
#  'jujur': 11954,
#  'keri': 12862,
#  'masyarakat': 15255,
#  'obat': 18075,
#  'racun': 20372,
#  'beda': 2570,
#  'dosis': 6799,
#  'uu': 25230,
#  'manusia': 15099,
#  'entar': 7360,
#  'jajah': 11499,
#  'bahaya': 2203,
#  'tubuh': 24726,
#  'indonesiadata': 10939,
#  'mingkem': 16071,
#  'scam': 21597,
#  'kemarin': 12692,
#  'danamon': 5226,
#  'bni': 3369,
#  'hati': 9184,
#  'guys': 8828,
#  'chat': 4635,
#  'nomor': 17741,
#  'klik': 13215,
#  'link': 14510,
#  'takut': 23573,
#  'saldo': 21335,
#  'hilang': 9391,
#  'halo': 9050,
#  'selamat': 21882,
#  'siang': 22405,
#  'konsumen': 13527,
#  'shopee': 22363,
#  'barusan': 2440,
#  'terima': 24039,
#  'telepon': 23872,
#  'tipu': 24349,
#  'mengatasnamakan': 15640,
#  'nama': 16647,
#  'lengkapalamat': 14364,
#  'mohon': 16269,
#  'tindak': 24312,
#  'case': 4452,
#  'resah': 20838,
#  'kasih': 12368,
#  'nik': 17595,
#  'beli': 2662,
#  'motormotornya': 16333,
#  'pajak': 18511,
#  'alamat': 1174,
#  'dunia': 6990,
#  'giring': 8509,
#  'tuju': 24752,
#  'digitalnanti': 5966,
#  'mudah': 16407,
#  'anjirkasian': 1526,
#  'hp': 9536,
#  'pulsa': 20244,
#  'internet': 11201,
#  'butuh': 4280,
#  'makan': 14889,
#  'susah': 23392,
#  'najis': 16632,
#  'hotel': 9527,
#  'kelas': 12630,
#  'unjung': 25068,
#  'fyi': 7947,
#  'spam': 22966,
#  '2017': 254,
#  'wajib': 25445,
#  'ulang': 24973,
#  'pakai': 18521,
#  'ktp': 13766,
#  'duduk': 6920,
#  'sampahmudah': 21388,
#  'update': 25104,
#  'temu': 23946,
#  'etc': 7448,
#  'suka': 23287,
#  'line': 14500,
#  'whatsapp': 25657,
#  'nomer': 17734,
#  'mikir': 15998,
#  'tuh': 24736,
#  'btc': 4105,
#  'sorr': 22919,
#  'bosan': 3908,
#  'harga': 9137,
#  'market': 15146,
#  'turun': 24831,
#  'kasihan': 12369,
#  'pinjol': 19525,
#  'gembel': 8305,
#  'kantor': 12279,
#  'ku': 13794,
#  'sop': 22899,
#  'buka': 4168,
#  'website': 25602,
#  'websiteapp': 25604,
#  'resmi': 20856,
#  'komputer': 13469,
#  'kantorkalo': 12282,
#  'auto': 2009,
#  'sapa': 21481,
#  'bi': 3026,
#  'salah': 21308,
#  'pegawai': 18903,
#  'teledor': 23853,
#  'ngelanggar': 17250,
#  'deh': 5507,
#  'rame': 20497,
#  'sekian': 21850,
#  'puluh': 20250,
#  'lengkap': 14362,
#  'lai': 14033,
#  'hudiya': 10573,
#  'bkl': 3245,
#  'kejar': 12594,
#  'sakya': 21304,
#  'personal': 19334,
#  'perusaahan': 19366,
#  'naye': 16798,
#  'doang': 6685,
#  'but': 4276,
#  'semoga': 21996,
#  'baning': 2342,
#  'cepat': 4553,
#  'ketangkep': 12948,
#  'biar': 3031,
#  'tenang': 23952,
#  'heran': 9309,
#  'tiktok': 24280,
#  'mah': 14839,
#  'ttangga': 24705,
#  'kerudung': 12897,
#  '30rb': 420,
#  'cod': 4810,
#  '80rb': 652,
#  'menerima': 15606,
#  'emaknya': 7240,
#  'langsung': 14139,
#  'bayar': 2505,
#  'cek': 4499,
#  'seller': 21932,
#  'lacak': 13957,
#  'maksud': 14930,
#  'ri': 20931,
#  'kencang': 12776,
#  'kominfo': 13374,
#  'suara': 23228,
#  'cuman': 5087,
#  'kayak': 12426,
#  'iya': 11431,
#  'gue': 8760,
#  'darimana': 5265,
#  '94': 686,
#  'sanksi': 21454,
#  'tegur': 23814,
#  'langgar': 14134,
#  'besarbesaran': 2943,
#  'hantam': 9104,
#  'india': 10872,
#  'identitas': 10696,
#  'detail': 5630,
#  'pribadi': 19957,
#  'online': 18219,
#  'iring': 11284,
#  'maju': 14882,
#  'teknologi': 23833,
#  'risiko': 20999,
#  'tingkat': 24326,
#  'milik': 16023,
#  'mobil': 16230,
#  'listrik': 14536,
#  'spklu': 23027,
#  'shell': 22336,
#  'jalan': 11515,
#  'menahan': 15550,
#  'nang': 16694,
#  'teror': 24092,
#  'psikis': 20176,
#  'kena': 12763,
#  'menikmati': 15725,
#  'duit': 6934,
#  'kagak': 12097,
#  'kemana2': 12666,
#  'indihome': 10882,
#  'enggak': 7326,
#  'mau': 15312,
#  'okeee': 18153,
#  'aman': 1289,
#  'nasib': 16765,
#  'datae': 5332,
#  'seng': 22075,
#  'ngunuku': 17542,
#  'piye': 19583,
#  'monggo': 16287,
#  'sangkut': 21449,
#  'lohojok': 14615,
#  'takok': 23568,
#  'ta': 23491,
#  'wes': 25640,
#  'biometric': 3143,
#  'ragu': 20393,
#  'kali': 12158,
#  'institusi': 11143,
#  'korporasi': 13609,
#  'negara': 16848,
#  'state': 23124,
#  'surveilllance': 23381,
#  'prc': 19905,
#  'mek': 15429,
#  'ngandani': 17043,
#  'sing': 22574,
#  'iki': 10759,
#  'iso': 11322,
#  'lho': 14429,
#  'menuntut': 15809,
#  'jaga': 11479,
#  'rahasia': 20396,
#  'datasak': 5395,
#  'uopooo': 25097,
#  'tunjukkan': 24813,
#  'sistem': 22638,
#  'ufah': 24931,
#  'kecap': 12533,
#  'lo': 14567,
#  'ngab': 16970,
#  'dongok': 6765,
#  'februari': 7666,
#  '1998': 198,
#  'puncak': 20254,
#  'oktober': 18167,
#  'paska': 18738,
#  'bupati': 4241,
#  'jawa': 11607,
#  '1999': 199,
#  'minim': 16074,
#  'literasi': 14544,
#  'tolol': 24491,
#  'menyampah': 15821,
#  'twiter': 24860,
#  'bertahun2': 2906,
#  '2023': 280,
#  'bahas': 2198,
#  'rumor': 21182,
#  'katrol': 12407,
#  'saham': 21266,
#  'label': 13952,
#  'artis': 1820,
#  'nyaman': 17922,
#  'parah': 18678,
#  'abang': 722,
#  'wamil': 25491,
#  'kacau': 12054,
#  'balau': 2261,
#  'nasabah': 16746,
#  'bsi': 4079,
#  'ojk': 18137,
#  'awas': 2039,
#  'komplen': 13457,
#  'berbusah2': 2797,
#  'gakan': 8046,
#  'wkwkwk': 25779,
#  'yaudah': 26087,
#  'ikhlas': 10755,
#  'ulah': 24970,
#  'hooo': 9512,
#  'kapal': 12290,
#  'bekas': 2641,
#  'mahal': 14842,
#  'nyata': 17952,
#  'hitung': 9430,
#  'investigasi': 11251,
#  'media': 15391,
#  'bredel': 4010,
#  'blackrock': 3269,
#  'kelola': 12649,
#  'dana': 5224,
#  'pensiun': 19159,
#  'vanguard': 25283,
#  'eksklusif': 7157,
#  'masuktapi': 15248,
#  'panama': 18592,
#  'paper': 18670,
#  'dll': 6629,
#  'pindah': 19510,
#  'amrik': 1387,
#  'gin': 8482,
#  'lets': 14391,
#  'sayang': 21560,
#  'kepake': 12804,
#  'alah': 1169,
#  'tahi': 23532,
#  'kotok': 13641,
#  'niat': 17567,
#  'selamatin': 21883,
#  'dukun': 6951,
#  'eh': 7109,
#  'gera': 8364,
#  'ninja': 17634,
#  'pecah': 18863,
#  'geger': 8265,
#  'santet': 21469,
#  'cegah': 4496,
#  'serang': 22172,
#  'masif': 15196,
#  'manfaat': 15040,
#  'jatuh': 11599,
#  'orde': 18332,
#  'betulbanget': 2974,
#  'percaya': 19221,
#  'id': 10677,
#  'selfie': 21920,
#  'toko': 24456,
#  'ijo': 10748,
#  'oren': 18339,
#  'rip': 20991,
#  'privacy': 20003,
#  'tolong': 24499,
#  'tulis': 24773,
#  'lolos': 14632,
#  'lupa': 14748,
#  'email': 7233,
#  'berkas': 2850,
#  'isi': 11305,
#  'web': 25587,
#  'rekrutmen': 20737,
#  'hapus': 9116,
#  'total': 24533,
#  'gagal': 8011,
#  'tes': 24142,
#  'kait': 12118,
#  'download': 6807,
#  'aplikasi': 1724,
#  'ilegal': 10782,
#  'uang': 24888,
#  'masuk': 15242,
#  'rekening': 20723,
#  'mencolong': 15583,
#  'modem': 16248,
#  'salam': 21332,
#  'sejahtera': 21813,
#  'credit': 5014,
#  'collector': 4838,
#  'akses': 1105,
#  'jtk': 11901,
#  'maklumat': 14911,
#  'hutang': 10614,
#  'legal': 14294,
#  'jaring': 11579,
#  'smartfren': 22768,
#  'trouble': 24665,
#  'paket': 18538,
#  'habiss': 8871,
#  'wkwkw': 25775,
#  'minn': 16093,
#  'murah': 16487,
#  'kantong': 12277,
#  'nih': 17578,
#  'saran': 21490,
#  'hehe': 9256,
#  'gratis': 8711,
#  'coblos': 4804,
#  'ganjar': 8122,
#  'den': 5550,
#  'bokep': 3841,
#  'maaf': 14779,
#  'sumpah': 23318,
#  'incompetency': 10853,
#  'ngerugiin': 17349,
#  'njiiiiir': 17669,
#  'database': 5312,
#  'bkpsdm': 3254,
#  'kabupaten': 12046,
#  'sampang': 21391,
#  'retas': 20890,
#  'hacker': 8884,
#  'milad': 16013,
#  'leaks': 14258,
#  'sensitif': 22100,
#  'pns': 19703,
#  'lingkung': 14504,
#  'pemkab': 19028,
#  'potong': 19852,
#  'nder': 16822,
#  'habis': 8865,
#  'tarik': 23704,
#  'minus': 16114,
#  'wokwwowkwowlw': 25856,
#  'get': 8394,
#  'contact': 4917,
#  'curiga': 5105,
#  'kandung': 12255,
#  'bukaaan': 4169,
#  'mbankingnya': 15343,
#  'error': 7414,
#  'min': 16048,
#  'telponin': 23909,
#  'asuransi': 1928,
#  'life': 14462,
#  'telpon': 23906,
#  'app': 1742,
#  'peniputapi': 19140,
#  'no': 17696,
#  'menunggu': 15808,
#  'cetak': 4587,
#  'mbak': 15337,
#  'lurah': 14758,
#  'disuru': 6480,
#  'donlot': 6775,
#  'digital': 5946,
#  'mudahan': 16408,
#  'kemendagri': 12713,
#  'dont': 6779,
#  'mess': 15927,
#  'this': 24219,
#  'one': 18209,
#  'up': 25098,
#  'dmn2': 6669,
#  'lu': 14701,
#  'sebar': 21685,
#  'jail': 11496,
#  'mending': 15594,
#  'ganti': 8130,
#  'lazadong': 14235,
#  'info': 10983,
#  'langgan': 14132,
#  'just': 11993,
#  'baca': 2122,
#  'bakar': 2242,
#  'yaudahlah': 26088,
#  'belanja': 2658,
#  'favorit': 7646,
#  'ep': 7381,
#  'nextmya': 16961,
#  'wkwk': 25756,
#  'tanggal': 23642,
#  'telp': 23903,
#  '02130200368': 7,
#  'menawari': 15571,
#  'cimb': 4715,
#  'ngambil': 17023,
#  'freeport': 7887,
#  '100': 31,
#  'katanyangambil': 12393,
#  'pilot': 19498,
#  'culik': 5082,
#  'sulitsama': 23304,
#  'wowo': 25899,
#  'buta': 4277,
#  'databocor': 5317,
#  'ria': 20932,
#  'laptop': 14176,
#  'disalahin': 6373,
#  'karyawan': 12351,
#  'era': 7396,
#  'rawan': 20584,
#  'kecuali': 12551,
#  'pln': 19658,
#  'nak': 16634,
#  'cakap': 4353,
#  'malaysia': 14946,
#  'rakyat': 20451,
#  'daftar': 5166,
#  'mysejahtera': 16565,
#  'samping': 21401,
#  'job': 11831,
#  'portal': 19818,
#  'bawa': 2488,
#  'hape': 9108,
#  'batre': 2480,
#  'tetheringan': 24161,
#  'kabel': 12038,
#  'android': 1448,
#  'ip': 11263,
#  'pbnya': 18833,
#  'yaampun': 25980,
#  'kak': 12122,
#  'ngemc': 17287,
#  'perintah': 19268,
#  'mesti': 15931,
#  'ijazah': 10743,
#  'minimal': 16075,
#  'd3': 5149,
#  'lulus': 14732,
#  'smk': 22780,
#  'alam': 1172,
#  'lihat': 14468,
#  'disubmit': 6475,
#  'duluan': 6960,
#  'gampang': 8103,
#  'mengasih': 15638,
#  'kadang': 12068,
#  'tagih': 23523,
#  'dasar': 5291,
#  'meter': 15949,
#  'asumsi': 1925,
#  'gara': 8151,
#  'tugas': 24734,
#  'catat': 4462,
#  'plnnya': 19663,
#  'menembak': 15601,
#  'visit': 25360,
#  'rumah2': 21172,
#  'baneran': 2294,
#  'dibenerin': 5789,
#  'disdukcapil': 6405,
#  'otonomi': 18385,
#  'dinas': 6196,
#  'tri': 24633,
#  'mou': 16335,
#  'phew': 19424,
#  'pagi': 18488,
#  'peras': 19208,
#  'sosial': 22925,
#  'pade': 18481,
#  'luas': 14707,
#  'paranormal': 18686,
#  'obl': 18079,
#  'survey': 23382,
#  'bpjs': 3948,
#  'uups': 25238,
#  'wakil': 25463,
#  'menteri': 15780,
#  'bumn': 4214,
#  'ii': 10739,
#  'kartika': 12339,
#  'wirjoatmodjo': 25716,
#  'ambil': 1339,
#  'cabang': 4328,
#  'duh': 6928,
#  'aneh': 1452,
#  'bri': 4016,
#  'siber': 22437,
#  'wamen': 25490,
#  'jenis': 11719,
#  'byu': 4321,
#  'sik': 22502,
#  'asik': 1862,
#  'sms': 22789,
#  'mulu': 16443,
#  'pinjam': 19520,
#  'sosmed': 22931,
#  'nit': 17654,
#  'kampus': 12222,
#  'tuanya': 24720,
#  'valeri': 25269,
#  'jo': 11830,
#  'staff': 23091,
#  'khusus': 13051,
#  'toyota': 24543,
#  'rugi': 21160,
#  'edward': 7070,
#  'snowden': 22818,
#  '10': 30,
#  'kawal': 12415,
#  'httpstcoafbsu8zxpb': 9748,
#  'washington': 25548,
#  '2013': 250,
#  'kontraktor': 13561,
#  'as': 1830,
#  'kejut': 12602,
#  'dedah': 5476,
#  'bah': 2189,
#  'teman': 23918,
#  'konfirmasi': 13492,
#  'suruh': 23377,
#  'gunain': 8788,
#  'capek': 4415,
#  'ohhhhh': 18122,
#  'js': 11898,
#  'kah': 12108,
#  'ditindaklanjuti': 6544,
#  'sembarang': 21968,
#  'disayngkan': 6392,
#  'bingung': 3125,
#  'pesan': 19380,
#  'datadata': 5326,
#  'sesuai': 22263,
#  'lapor': 14168,
#  'kemana': 12665,
#  'kuatir': 13810,
#  'cs': 5035,
#  'gaperlu': 8142,
#  'selesai': 21910,
#  'urus': 25143,
#  'psikolog': 20178,
#  'sesi': 22257,
#  'konsultasi': 13526,
#  'lenyap': 14372,
#  'cari': 4444,
#  'arti': 1815,
#  'dokumen': 6728,
#  'anggap': 1467,
#  'intern': 11193,
#  'twitter': 24864,
#  'please': 19642,
#  'your': 26158,
#  'magic': 14835,
#  'ngaku2': 17005,
#  'lazada': 14233,
#  'rumah': 21171,
#  'barang': 2412,
#  'nelpon': 16896,
#  'ngisi': 17440,
#  'bicara': 3055,
#  'kasar': 12359,
#  'customer': 5111,
#  'tibatiba': 24260,
#  'us': 25155,
#  'asli': 1877,
#  'wkwkwkwk': 25801,
#  'user': 25179,
#  'kontak': 13538,
#  'real': 20606,
#  'ancam': 1415,
#  'joki': 11855,
#  'backup': 2134,
#  'syukur': 23479,
#  'fee': 7670,
#  'informasi': 10998,
#  'simpeg': 22547,
#  'skp': 22715,
#  'tinggal': 24320,
#  'negeri': 16875,
#  'wakanda': 25459,
#  'takutdi': 23576,
#  'nope': 17772,
#  'dengar': 5558,
#  'atm': 1959,
#  'bobol': 3387,
#  'bom': 3855,
#  'rutin': 21209,
#  'sopi': 22904,
#  'pp': 19861,
#  'akun': 1143,
#  'sopay': 22902,
#  'later': 14197,
#  'hybrid': 10634,
#  'kian': 13058,
#  'jamur': 11542,
#  'rentan': 20794,
#  'miris': 16125,
#  'management': 15009,
#  'konser': 13517,
#  'sangka': 21445,
#  'sidi': 22459,
#  'kpk': 13659,
#  'santuy': 21474,
#  'jabat': 11463,
#  'jkw': 11811,
#  'foto': 7851,
#  'papa': 18663,
#  'mengaca': 15611,
#  'muji': 16425,
#  'hasil': 9172,
#  'diet': 5921,
#  'simpan': 22542,
#  'bentuk': 2750,
#  'rnd': 21040,
#  'ternyta': 24083,
#  'analisis': 1405,
#  'eksternal': 7172,
#  'apa': 1627,
#  'gambar': 8080,
#  'qty': 20346,
#  'production': 20047,
#  'pengaruh': 19095,
#  'pricing': 19984,
#  'komponen': 13460,
#  'unit': 25060,
#  'bocorberarti': 3461,
#  'valid': 25270,
#  'curang': 5097,
#  'sistematis': 22640,
#  'layak': 14223,
#  'tangkap': 23662,
#  'ketua': 13000,
#  'toch': 24438,
#  'khawatir': 13037,
#  'besok': 2950,
#  'proses': 20109,
#  'hukum': 10588,
#  'wni': 25839,
#  'dukung': 6953,
#  'jkwwalau': 11813,
#  'maya': 15322,
#  'kpkyg': 13661,
#  'mengikuti': 15696,
#  '60rbpas': 588,
#  'join': 11847,
#  'group': 8730,
#  'telegram': 23855,
#  'blokir': 3319,
#  'ajasaran': 1031,
#  'ponsel': 19788,
#  'utama': 25207,
#  'mengaku': 15622,
#  'telkomsel': 23896,
#  'bilang': 3093,
#  'pencet': 19063,
#  'angka': 1480,
#  'karen': 12321,
#  'kaget': 12101,
#  'gaakan': 7958,
#  'laku': 14083,
#  'ratus': 20579,
#  'ribu': 20946,
#  'bocorhttpstco2fuhljwcng': 3546,
#  'anwar': 1601,
#  'usman': 25195,
#  'mengomong': 15709,
#  'putus': 20314,
#  'lanjur': 14142,
#  'ngefoto': 17193,
#  'hiiatut': 9380,
#  'contoh': 4926,
#  'resiko': 20853,
#  'kendali': 12782,
#  'penuh': 19179,
#  'memutuskan': 15539,
#  'konten': 13543,
#  'nemu': 16908,
#  'hindar': 9405,
#  'dapur': 5258,
#  'klarifikasi': 13193,
#  'denny': 5571,
#  'indrayana': 10968,
#  'mahkamah': 14857,
#  'konstitusi': 13524,
#  'narasi': 16731,
#  'milu': 16039,
#  'keliru': 12644,
#  'bahasa': 2199,
#  'sisi': 22633,
#  '2019': 260,
#  'kontrak': 13559,
#  'ekslusifnya': 7159,
#  'cancel': 4386,
#  'adil': 838,
#  'payment': 18816,
#  'fair': 7578,
#  'kai': 12112,
#  'muka': 16428,
#  'gimanatapi': 8474,
#  'asia': 1857,
#  'arisan': 1801,
#  'kirim': 13110,
#  'kakak': 12124,
#  'tf': 24172,
#  '15jt': 141,
#  'digunain': 5984,
#  'hal': 9034,
#  'bantu': 2375,
#  'rt': 21139,
#  'kronologi': 13738,
#  'ceritain': 4576,
#  'useless': 25176,
#  'bungkus': 4228,
#  'goreng': 8662,
#  'nasi': 16764,
#  'bocorin': 3563,
#  'asa': 1831,
#  '102juta': 53,
#  'tqpi': 24551,
#  'hadap': 8927,
#  'fakta': 7594,
#  'edan': 7058,
#  'doktor': 6724,
#  'bukti': 4187,
#  'konoon': 13509,
#  'konyol': 13569,
#  'status': 23140,
#  'bareskrim': 2426,
#  'integritas': 11167,
#  'keluarga': 12653,
#  'surat': 23361,
#  'ppatk': 19863,
#  'antero': 1580,
#  '40000': 481,
#  'goldheart': 8624,
#  'dakwa': 5201,
#  'tali': 23587,
#  'kuasa': 13803,
#  'sg': 22314,
#  'siasat': 22432,
#  'httpstcox3yba3dldl': 10489,
#  'singapura': 22580,
#  'godam': 8608,
#  'thanks': 24190,
#  'biometrik': 3144,
#  'umbar2': 24992,
#  'oh': 18119,
#  'peribadi': 19251,
#  'mate': 15290,
#  'fhm': 7698,
#  'httpstco82ope3n4oh': 9701,
#  'canggih': 4391,
#  'ken': 12762,
#  'warga': 25514,
#  'konoha': 13506,
#  'sehari2': 21804,
#  'serba': 22179,
#  'unt': 25084,
#  'sera': 22162,
#  'truk': 24678,
#  'guling': 8780,
#  'uninstall': 25055,
#  'sehat': 21806,
#  'arep': 1790,
#  'nyengkeram': 17994,
#  'kim': 13084,
#  'jong': 11871,
#  'un': 25010,
#  'toilet': 24448,
#  'pergi': 19243,
#  'musuh': 16517,
#  'curi': 5102,
#  'diaitu': 5699,
#  'intelijen': 11179,
#  'undi': 25032,
#  'belikan': 2670,
#  'oceania': 18094,
#  'kabar': 12029,
#  'kendara': 12783,
#  'membedakan': 15480,
#  'smartphone': 22769,
#  'lidi': 14457,
#  'digit': 5945,
#  '62': 593,
#  'berita': 2833,
#  'mediamedia': 15394,
#  'medis': 15399,
#  'wenang': 25637,
#  'organisasi': 18345,
#  'profesi': 20060,
#  'kolegium': 13329,
#  'konsil': 13518,
#  'dokter': 6722,
#  'alih': 1231,
#  'paksa': 18556,
#  'omnibuslawpadahal': 18195,
#  'nakes': 16638,
#  'ahli': 964,
#  'mugkin': 16418,
#  'sdm': 21657,
#  'inijika': 11051,
#  'uuharus': 25233,
#  'deteksi': 5638,
#  'hubung': 10568,
#  'etika': 7457,
#  'profesiboleh': 20061,
#  'indak': 10857,
#  'omnibuslaw': 18194,
#  'tangan': 23625,
#  'tahan': 23527,
#  'nasional': 16768,
#  'bayang': 2501,
#  'next': 16958,
#  'pening': 19121,
#  'bangsa': 2326,
#  'buah': 4114,
#  'peta': 19396,
#  'asai': 1834,
#  'asingtiada': 1869,
#  'yuk': 26175,
#  'fix': 7776,
#  'minggu': 16068,
#  'ditlf': 6548,
#  'kenal': 12765,
#  'truecaller': 24677,
#  'dinamain': 6194,
#  'bersama2': 2881,
#  'bnl': 3371,
#  'alas': 1186,
#  'bantuin': 2377,
#  'indonesiadaripada': 10938,
#  'daya': 5427,
#  'thread': 24235,
#  'sponsor': 23035,
#  'liga': 14465,
#  'pasword': 18781,
#  'banking': 2354,
#  'tutup': 24838,
#  'inna': 11097,
#  'lillahi': 14479,
#  'claimed': 4760,
#  'rem': 20758,
#  'khayal': 13042,
#  'genomik': 8351,
#  'ngeri': 17334,
#  'dikirimin': 6089,
#  'sakit': 21295,
#  'bida': 3058,
#  'lamar': 14102,
#  'jobstreet': 11836,
#  'oke': 18149,
#  'ges': 8386,
#  'fud': 7915,
#  'hormat': 9518,
#  'teriak': 24034,
#  'ramai': 20487,
#  'diamtakut': 5727,
#  'rezimkl': 20927,
#  'pastisidang': 18777,
#  'nmn': 17689,
#  'tertutupinila': 24122,
#  'rezim': 20926,
#  'dipertontankan': 6270,
#  '9thn': 697,
#  'sanggup': 21444,
#  'genome': 8350,
#  'bocorjadi': 3580,
#  'slowly': 22758,
#  'bunuh': 4238,
#  'bikin': 3087,
#  'substance': 23248,
#  ...}

# %%
new_df = pd.read_csv('./csvfile/labeled_df.csv')
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22741 entries, 0 to 22740
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       22741 non-null  object
#  1   content    22741 non-null  object
#  2   polarity   22741 non-null  int64
#  3   sentiment  22741 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 710.8+ KB

# %%
y = new_df['sentiment']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=200, random_state=42)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
pred = rf.predict(X_test)

# %%
print(classification_report(y_test, pred))
print(accuracy_score(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      4352
#            1       0.88      0.05      0.10       135
#            2       1.00      0.11      0.20        62
#
#     accuracy                           0.96      4549
#    macro avg       0.94      0.39      0.43      4549
# weighted avg       0.96      0.96      0.94      4549
#
# 0.9595515497911629

# %%
from sklearn import svm

clf = svm.SVC()
clf.fit(X_train, y_train)
# Out:
# SVC()

# %%
pred_2 = clf.predict(X_test)

# %%
print(classification_report(y_test, pred_2))
print(accuracy_score(y_test, pred_2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      4352
#            1       0.90      0.07      0.12       135
#            2       1.00      0.03      0.06        62
#
#     accuracy                           0.96      4549
#    macro avg       0.95      0.37      0.39      4549
# weighted avg       0.96      0.96      0.94      4549
#
# 0.9588920641899319
