# %%
import pandas as pd
df = pd.read_csv('Scraping_preprocessing_v3.csv')
content = df['content']
content = content.dropna().tolist()

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(ngram_range=(1,2))
X_train = cv.fit_transform(content)

# %%
cv.vocabulary_
# Out:
# {'abai': 2306,
#  'dishare': 42425,
#  'manis': 91450,
#  'nya': 107994,
#  'ruu': 129768,
#  'kesehatanyang': 77742,
#  'halusinasi': 56677,
#  'tanggung': 144051,
#  'jawabkantanya': 67848,
#  'data': 34516,
#  'genom': 51995,
#  'bocor': 20470,
#  'abai dishare': 2311,
#  'dishare manis': 42433,
#  'manis nya': 91453,
#  'nya ruu': 108505,
#  'ruu kesehatanyang': 129772,
#  'kesehatanyang halusinasi': 77743,
#  'halusinasi tanggung': 56679,
#  'tanggung jawabkantanya': 144150,
#  'jawabkantanya data': 67849,
#  'data genom': 35572,
#  'genom bocor': 51997,
#  'bocor tanggung': 24273,
#  'stunting': 141305,
#  'jamban': 67321,
#  'bersih': 16800,
#  'alat': 5034,
#  'usg': 154687,
#  'tbc': 145275,
#  'mati': 93062,
#  'lahir': 83592,
#  'duga': 44750,
#  'jual': 69003,
#  'juta': 69702,
#  'pasien': 114854,
#  'diserver': 42417,
#  'kemenkes': 76025,
#  'kerja': 77178,
#  'buruk': 28424,
#  'sejarahso': 133280,
#  'stunting jamban': 141306,
#  'jamban bersih': 67322,
# ...
